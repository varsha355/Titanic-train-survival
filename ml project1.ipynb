# %%
import numpy as  np  #for multidim arrays
import pandas as pd  #dataframes
import seaborn as sns
import matplotlib.pyplot as plt  #datavisualization
import warnings
warnings.simplefilter("ignore")

train=pd.read_csv('titanic_train.csv')
test=pd.read_csv('titanic_test.csv')
# Out:
#      PassengerId  Pclass                          Name     Sex   Age  SibSp  \
# 413         1305       3            Spector, Mr. Woolf    male   NaN      0
# 414         1306       1  Oliva y Ocana, Dona. Fermina  female  39.0      0
# 415         1307       3  Saether, Mr. Simon Sivertsen    male  38.5      0
# 416         1308       3           Ware, Mr. Frederick    male   NaN      0
# 417         1309       3      Peter, Master. Michael J    male   NaN      1
#
#      Parch              Ticket      Fare Cabin Embarked
# 413      0           A.5. 3236    8.0500   NaN        S
# 414      0            PC 17758  108.9000  C105        C
# 415      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416      0              359309    8.0500   NaN        S
# 417      1                2668   22.3583   NaN        C

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
train.head()
train.tail()
test.head()
test.tail()
train.shape
test.shape

# %%
test.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
train.duplicated().sum()
# Out:
# 0

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test.duplicated().sum()

# %%
train.columns

# %%
Survived=pd.DataFrame(Survived)
display(Survived)

# %%
train.shape

# %%
train.info()

# %%
train.describe()

# %%
test.describe()

# %%
train.nunique()

# %%
test.nunique()

# %%
train_num=train[['Age','SibSp','Parch','Fare']]
train_cat=train[['Survived','Pclass','Sex','Ticket','Cabin','Embarked']]
train_num.shape

# %%
plt.hist(train_num['Age'],bins=10)
plt.title("Age")
plt.show()

# %%
sns.histplot(train_num['Age'],bins=10)
plt.title("Age")
plt.show()

# %%
sns.histplot(train_num['SibSp'],bins=10)
plt.title("Siblng/spouse")
plt.show()

# %%
sns.histplot(train_num['Parch'],bins=10)
plt.title("Parent/Child")
plt.show()

# %%
plt.hist(train_num['Parch'],bins=10)
plt.title("Parent/Child")
plt.show()

# %%
sns.histplot(train_num['Fare'],bins=10)
plt.title("Fare")
plt.show()

# %%
train_cat['Survived'].nunique()

# %%
train_cat['Survived'].value_counts()

# %%
Survived=Survived.reset_index()
display(Survived)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-bdb70e7af6c4> in <module>()
# ----> 1 Survived=Survived.reset_index()
#       2 display(Survived)
#
# NameError: name 'Survived' is not defined

# %%
sns.countplot(train_cat['Survived'],data = train_cat,palette='hls')
plt.title("Survived")
plt.xticks(rotation=45)
plt.show()

# %%
for i in train_cat.columns:

  plt.figure(figsize=(15,6))
  sns.countplot(train_cat[i],data=train_cat,palette='hls')
  plt.xticks(rotation=45)
  plt.show()

# %%
sns.pairplot(train_num)
plt.show()

# %%
print(train_num.corr())

# %%
plt.figure(figsize=(15,15))
cmap=sns.diverging_palette(178,10,s=50,l=55,n=18,as_cmap=True)
sns.heatmap(train_num.corr(),annot=True,cmap=cmap,center=0)
plt.show()

# %%
pd.pivot_table(train,index='Survived',values=['Age','SibSp','Parch','Fare'])

# %%
import numpy as  np  #for multidim arrays
import pandas as pd  #dataframes
import seaborn as sns
import matplotlib.pyplot as plt  #datavisualization
import warnings
warnings.simplefilter("ignore")

train=pd.read_csv('titanic_train.csv')
test=pd.read_csv('titanic_test.csv')

train_num=train[['Age','SibSp','Parch','Fare']]
train_cat=train[['Survived','Pclass','Sex','Ticket','Cabin','Embarked']]
train_num.shape
Survived=train_cat["Survived"].value_counts(normalize=True)
Survived=pd.DataFrame(Survived)
Survived=Survived.reset_index()
Survived=Survived.rename(columns={"index":"Survived","Survived":"% of Survivors"})
Survived=Survived.sort_values(by='Survived')
Survived["% of Survivors"]=Survived["% of Survivors"]*100
Survived["% of Survivors"]=np.round(Survived["% of Survivors"])
display(Survived)

plt.figure(figsize=(6,5))
sns.barplot(x='Survived',y='% of Survivors',data=Survived)
plt.title("Percent of Survivals")
plt.show()
Survived=Survived.reset_index()
display(Survived)
# Out:
#    Survived  % of Survivors
# 0         0            62.0
# 1         1            38.0
#    index  Survived  % of Survivors
# 0      0         0            62.0
# 1      1         1            38.0

# %%
import numpy as  np  #for multidim arrays
import pandas as pd  #dataframes
import seaborn as sns
import matplotlib.pyplot as plt  #datavisualization
import warnings
warnings.simplefilter("ignore")

train=pd.read_csv('titanic_train.csv')
test=pd.read_csv('titanic_test.csv')

train_num=train[['Age','SibSp','Parch','Fare']]
train_cat=train[['Survived','Pclass','Sex','Ticket','Cabin','Embarked']]

Sex=train_cat["Sex"].value_counts(normalize=True)
Sex=pd.DataFrame(Sex)
Sex=Sex.reset_index()
Sex=Sex.rename(columns={"index":"Sex","Sex":"% of passengers"})
Sex=Sex.sort_values(by='Sex')
Sex["% of passengers"]=Sex["% of passengers"]*100
Sex["% of passengers"]=np.round(Sex["% of passengers"],2)
display(Sex)
# Out:
#       Sex  % of passengers
# 1  female            35.24
# 0    male            64.76
#      Survived  Pclass     Sex   Age   Fare
# 886         0       2    male  27.0  13.00
# 887         1       1  female  19.0  30.00
# 888         0       3  female   NaN  23.45
# 889         1       1    male  26.0  30.00
# 890         0       3    male  32.0   7.75

# %%
train=train[["Survived","Pclass","Sex","Age","Fare"]]
train.head()
train.tail()

# %%
train.isnull().sum()

# %%
train.groupby('Sex')['Age'].mean()

# %%
test_x=test[['Pclass','Sex','Age','Fare']]
test_x.head()
test_x.groupby('Sex')['Age'].mean()

# %%
train['Age']=train.groupby("Sex")['Age'].transform(lambda x:x.fillna(x.mean()))#fill null values using fillna

# %%
test_x['Age']=test_x.groupby("Sex")['Age'].transform(lambda x:x.fillna(x.mean()))
test_x['Fare'].fillna(test_x['Fare'].mean(),inplace=True)

# %%
train.isnull().sum()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()#transorm labels to numeric values

# %%
train['Sex']=le.fit_transform(train.Sex)
train.head()
# Out:
#    Survived  Pclass  Sex   Age     Fare
# 0         0       3    1  22.0   7.2500
# 1         1       1    0  38.0  71.2833
# 2         1       3    0  26.0   7.9250
# 3         1       1    0  35.0  53.1000
# 4         0       3    1  35.0   8.0500

# %%
x=train[['Pclass','Sex','Age','Fare']]
y=train['Survived']

# %%
test_x['Sex']=le.fit_transform(test_x.Sex)
test_x.head()
# Out:
#    Pclass  Sex   Age     Fare
# 0       3    1  34.5   7.8292
# 1       3    0  47.0   7.0000
# 2       2    1  62.0   9.6875
# 3       3    1  27.0   8.6625
# 4       3    0  22.0  12.2875

# %%
x.isnull().sum()
# Out:
# Pclass    0
# Sex       0
# Age       0
# Fare      0
# dtype: int64

# %%
x.shape
# Out:
# (891, 4)

# %%
y.shape
# Out:
# (891,)

# %%
gender_sub_data=pd.read_csv('gender_submission.csv')
gender_sub_data.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         1
# 3          895         0
# 4          896         1

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.model_selection import train_test_split
y_train=train['Survived']
y_test=gender_sub_data["Survived"]

# %%
sc=StandardScaler()
x=sc.fit_transform(x)
test_x=sc.fit_transform(test_x)

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()
model.fit(x,y_train)

# %%
y_pred=model.predict(test_x)
print(y_pred)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       274
#            1       0.98      0.99      0.98       144
#
#     accuracy                           0.99       418
#    macro avg       0.99      0.99      0.99       418
# weighted avg       0.99      0.99      0.99       418

# %%
print("Training Accuracy:",model.score(x,y_train))
print("Testing Accuracy:"),model.score(test_x,y_test)
# Out:
# Training Accuracy: 0.9797979797979798
# Testing Accuracy:
# (None, 0.9880382775119617)

# %%
from sklearn import tree
plt.figure(figsize=(10,15))
tree.plot_tree(model,filled=True)
plt.show()

# %%
from sklearn.linear_model import LogisticRegression
classifier1=LogisticRegression(random_state=0)
classifier1.fit(x,y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
y_pred=classifier1.predict(test_x)

# %%
print("Training Accuracy:",classifier1.score(x,y_train))
print("Testing Accuracy:",classifier1.score(test_x,y_test))
# Out:
# Training Accuracy: 0.7991021324354658
# Testing Accuracy: 0.8086124401913876

# %%
from sklearn.ensemble import RandomForestClassifier
classifier2=RandomForestClassifier(n_estimators=10,criterion="entropy")
classifier2.fit(x,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10)

# %%
print("Training Accuracy:",classifier2.score(x,y_train))
print("Testing Accuracy:",classifier2.score(test_x,y_test))
# Out:
# Training Accuracy: 0.9652076318742986
# Testing Accuracy: 0.8947368421052632
